# %%
import pandas as pd  ### Load the Pandas libraries with alias 'pd'

# %%
### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html?highlight=sort_values#pandas.DataFrame.sort_values

##can refer above link

# %%
df=pd.read_csv("csv file.csv") ### Read data from file 'filename.csv' (in the same directory that your python process is based)
                               ###Control delimiters, rows, column names with read_csv (see later) 
                                #data = pd.read_csv("filename.csv")

# %%
df.head() ###Preview the first 5 lines of the loaded data...Parameters=n:int, default 5...df.head(n) 
           ##Number of rows to select.
# Out:
#                  hlpi_name  year   hlpi  tot_hhs      own  own_wm  own_prop  \
# 0           All households  2008  allhh  1560859  1087580  574406      69.7
# 1              Beneficiary  2008  benef   185965    71256   39405      38.3
# 2  Income quintile 1 (low)  2008  disq1   312376   191470   48424      61.3
# 3        Income quintile 2  2008  disq2   312333   196203   84171      62.8
# 4        Income quintile 3  2008  disq3   312240   217657  141318      69.7
#
#    own_wm_prop  prop_hhs   age  size  income  expenditure  eqv_income  eqv_exp
# 0         36.8     100.0  35.9   2.7   46704        42394       26869    25132
# 1         21.2      11.9  29.9   2.6   23404        25270       14258    15824
# 2         15.5      20.0  40.0   2.3   16747        21145       13402    14408
# 3         26.9      20.0  34.7   2.8   31308        29855       18917    18266
# 4         45.3      20.0  31.5   3.0   49106        46561       26870    24672

# %%
df.head(3) ##Viewing the first n lines (three in this case)
# Out:
#                  hlpi_name  year   hlpi  tot_hhs      own  own_wm  own_prop  \
# 0           All households  2008  allhh  1560859  1087580  574406      69.7
# 1              Beneficiary  2008  benef   185965    71256   39405      38.3
# 2  Income quintile 1 (low)  2008  disq1   312376   191470   48424      61.3
#
#    own_wm_prop  prop_hhs   age  size  income  expenditure  eqv_income  eqv_exp
# 0         36.8     100.0  35.9   2.7   46704        42394       26869    25132
# 1         21.2      11.9  29.9   2.6   23404        25270       14258    15824
# 2         15.5      20.0  40.0   2.3   16747        21145       13402    14408

# %%
df.head(-50) ##For negative values of n
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# 5               Income quintile 4  2008  disq4   312336   229014  147658
# 6        Income quintile 5 (high)  2008  disq5   311574   253235  152835
# 7    Expenditure quintile 1 (low)  2008  expq1   312761   194358   49448
# 8          Expenditure quintile 2  2008  expq2   311973   206342   86390
# 9          Expenditure quintile 3  2008  expq3   311840   194361  108065
# 10         Expenditure quintile 4  2008  expq4   312257   231612  149007
# 11  Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %%
df.tail() #Return the last 5 rows defaultly..df.tail(n)..[n=5]
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 65         Expenditure quintile 3  2020  expq3   352564  213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182  235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328  288779  187838
# 68                          Māori  2020  maori   329588  156459  107753
# 69                 Superannuitant  2020  super   388013  314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# 65      60.7         33.9      20.1  36.9   2.8   69779        57351
# 66      67.2         40.3      19.9  35.0   3.0   88944        83038
# 67      82.2         53.5      20.0  39.6   2.6  104277       123424
# 68      47.5         32.7      18.8  31.1   3.2   69581        54141
# 69      81.0          9.9      22.1  69.8   1.7   34712        34643
#
#     eqv_income  eqv_exp
# 65       38889    33468
# 66       48929    45978
# 67       62718    71985
# ...

# %%
df.tail(7) ##if (n=7)means returns last 7rows
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 63   Expenditure quintile 1 (low)  2020  expq1   352137  182056   45300
# 64         Expenditure quintile 2  2020  expq2   350530  198616   80783
# 65         Expenditure quintile 3  2020  expq3   352564  213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182  235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328  288779  187838
# 68                          Māori  2020  maori   329588  156459  107753
# 69                 Superannuitant  2020  super   388013  314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# 63      51.7         12.9      20.0  40.6   2.5   33200        20063
# 64      56.7         23.0      20.0  37.4   2.8   51756        40102
# 65      60.7         33.9      20.1  36.9   2.8   69779        57351
# 66      67.2         40.3      19.9  35.0   3.0   88944        83038
# ...

# %%
df.tail(-30) ##For negative values of n, this function returns all rows except the first n rows
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 30        Income quintile 1 (low)  2014  disq1   328349   171141   52691
# 31              Income quintile 2  2014  disq2   327432   190496   84148
# 32              Income quintile 3  2014  disq3   327566   219709  118724
# 33              Income quintile 4  2014  disq4   328158   237912  145756
# 34       Income quintile 5 (high)  2014  disq5   327900   271412  151260
# 35   Expenditure quintile 1 (low)  2014  expq1   327145   179585   41640
# 36         Expenditure quintile 2  2014  expq2   328033   191455   79697
# 37         Expenditure quintile 3  2014  expq3   328959   218610  113005
# 38         Expenditure quintile 4  2014  expq4   327692   229472  138029
# 39  Expenditure quintile 5 (high)  2014  expq5   327576   271549  180208
# 40                          Māori  2014  maori   287053   127885   85034
# 41                 Superannuitant  2014  super   357748   315121   41565
# ...

# %%
df.dropna() #DataFrame with NA entries dropped from it or None
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df.describe() #Summary statistics of the Series or Dataframe provided,For numeric data, the result’s index will include count,
              #mean, std, min, max as well as lower, 50 and upper percentiles. By default the lower percentile is 25 and the 
              #upper percentile is 75. The 50 percentile is the same as the median.
# Out:
#               year       tot_hhs           own         own_wm   own_prop  \
# count    70.000000  7.000000e+01  7.000000e+01      70.000000  70.000000
# mean   2014.000000  4.125193e+05  2.689711e+05  129639.457143  63.505714
# std       4.273274  3.491547e+05  2.385230e+05  128627.124758  15.145257
# min    2008.000000  1.322150e+05  3.008000e+04   14220.000000  22.800000
# 25%    2011.000000  3.123460e+05  1.838408e+05   50636.750000  55.400000
# 50%    2014.000000  3.276340e+05  2.153065e+05  107909.000000  64.200000
# 75%    2017.000000  3.468958e+05  2.604148e+05  147563.000000  73.675000
# max    2020.000000  1.756740e+06  1.125000e+06  574662.000000  88.100000
#
#        own_wm_prop    prop_hhs        age       size         income  \
# count    70.000000   70.000000  70.000000  70.000000      70.000000
# mean     30.348571   24.985714  38.284286   2.625714   56694.785714
# std      14.010004   21.102368   9.376345   0.350439   28921.315551
# ...

# %%
df.info() #This method prints information about a DataFrame including the index dtype and columns, non-null values and memory 
          #usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hlpi_name    70 non-null     object
#  1   year         70 non-null     int64
#  2   hlpi         70 non-null     object
#  3   tot_hhs      70 non-null     int64
#  4   own          70 non-null     int64
#  5   own_wm       70 non-null     int64
#  6   own_prop     70 non-null     float64
#  7   own_wm_prop  70 non-null     float64
#  8   prop_hhs     70 non-null     float64
#  9   age          70 non-null     float64
#  10  size         70 non-null     float64
#  11  income       70 non-null     int64
#  12  expenditure  70 non-null     int64
#  13  eqv_income   70 non-null     int64
#  14  eqv_exp      70 non-null     int64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 8.3+ KB

# %%
df.fillna ##Fill NA/NaN values using the specified method
# Out:
# <bound method DataFrame.fillna of                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
# ...

# %%
df.sort_values(by=['year', 'own'])##Sort by the values along either axis...Sort by multiple columns
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 12                          Māori  2008  maori   253018   119963   77076
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 7    Expenditure quintile 1 (low)  2008  expq1   312761   194358   49448
# 9          Expenditure quintile 3  2008  expq3   311840   194361  108065
# ..                            ...   ...    ...      ...      ...     ...
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 62       Income quintile 5 (high)  2020  disq5   350840   282193  170510
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 69                 Superannuitant  2020  super   388013   314154   38270
# 56                 All households  2020  allhh  1756740  1118600  574662
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df.sort_values(by=['income'])##Sort by sigle columns..by default sort in ascending order
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 2         Income quintile 1 (low)  2008  disq1   312376  191470   48424
# 16        Income quintile 1 (low)  2011  disq1   321848  166355   49952
# 58        Income quintile 1 (low)  2020  disq1   353215  202923   54851
# 13                 Superannuitant  2008  super   300243  263054   15406
# 44        Income quintile 1 (low)  2017  disq1   337948  182696   43443
# ..                            ...   ...    ...      ...     ...     ...
# 20       Income quintile 5 (high)  2011  disq5   320751  262660  142986
# 53  Expenditure quintile 5 (high)  2017  expq5   337496  281016  172895
# 34       Income quintile 5 (high)  2014  disq5   327900  271412  151260
# 48       Income quintile 5 (high)  2017  disq5   338027  286886  160865
# 62       Income quintile 5 (high)  2020  disq5   350840  282193  170510
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df.sort_values(by='expenditure', ascending=False) ##Sort in Descending order
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 67  Expenditure quintile 5 (high)  2020  expq5   351328  288779  187838
# 53  Expenditure quintile 5 (high)  2017  expq5   337496  281016  172895
# 62       Income quintile 5 (high)  2020  disq5   350840  282193  170510
# 39  Expenditure quintile 5 (high)  2014  expq5   327576  271549  180208
# 48       Income quintile 5 (high)  2017  disq5   338027  286886  160865
# ..                            ...   ...    ...      ...     ...     ...
# 49   Expenditure quintile 1 (low)  2017  expq1   338025  181960   32809
# 63   Expenditure quintile 1 (low)  2020  expq1   352137  182056   45300
# 35   Expenditure quintile 1 (low)  2014  expq1   327145  179585   41640
# 21   Expenditure quintile 1 (low)  2011  expq1   321611  173327   35941
# 7    Expenditure quintile 1 (low)  2008  expq1   312761  194358   49448
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df.groupby(['age']).mean()##Group DataFrame using a mapper or by a Series of columns...A groupby 
#operation involves some combination of splitting the object, applying a function, and combining the 
#results. This can be used to group large amounts of data and compute operations on these groups.
# Out:
#         year       tot_hhs           own         own_wm   own_prop  \
# age
# 27.3  2014.0  1.861340e+05  4.583400e+04   27032.000000  24.600000
# 28.0  2011.0  1.972370e+05  5.666500e+04   27129.000000  28.700000
# 28.3  2011.0  2.791280e+05  1.153120e+05   77879.000000  41.300000
# 28.9  2008.0  2.530180e+05  1.199630e+05   77076.000000  47.400000
# 29.1  2017.0  1.322150e+05  3.008000e+04   14220.000000  22.800000
# 29.9  2008.0  1.859650e+05  7.125600e+04   39405.000000  38.300000
# 30.2  2014.0  2.870530e+05  1.278850e+05   85034.000000  44.600000
# 31.1  2020.0  3.295880e+05  1.564590e+05  107753.000000  47.500000
# 31.5  2008.0  3.122400e+05  2.176570e+05  141318.000000  69.700000
# 31.7  2020.0  2.095590e+05  5.572300e+04   28429.000000  26.600000
# 32.0  2017.0  2.953220e+05  1.469790e+05   89146.000000  49.800000
# 33.0  2008.0  3.118400e+05  1.943610e+05  108065.000000  62.300000
# 33.4  2011.0  3.213720e+05  2.049570e+05  119746.000000  63.800000
# ...

# %%
df.groupby(by="income").sum() ## for summing the income
# Out:
#         year  tot_hhs     own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# income
# 16747   2008   312376  191470   48424      61.3         15.5      20.0  40.0
# 19787   2011   321848  166355   49952      51.7         15.5      20.0  36.3
# 20816   2020   353215  202923   54851      57.5         15.5      20.1  41.1
# 22367   2008   300243  263054   15406      87.6          5.1      19.2  70.3
# 22733   2017   337948  182696   43443      54.1         12.9      20.0  40.3
# ...      ...      ...     ...     ...       ...          ...       ...   ...
# 106227  2011   320751  262660  142986      81.9         44.6      20.0  40.9
# 109930  2017   337496  281016  172895      83.3         51.2      20.0  38.3
# 122881  2014   327900  271412  151260      82.8         46.1      20.0  41.0
# 133270  2017   338027  286886  160865      84.9         47.6      20.0  41.1
# 146672  2020   350840  282193  170510      80.4         48.6      20.0  39.8
#
# ...

# %%
df.apply
# Out:
# <bound method DataFrame.apply of                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
# ...

# %%
df.append ##Append rows of other to the end of caller, returning a new object.
# Out:
# <bound method DataFrame.append of                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
# ...

# %%
df.join ##Join columns of another DataFrame....Join columns with other DataFrame either on index or on
#a key column.Efficiently join multiple DataFrame objects by index at once by passing a list.
# Out:
# <bound method DataFrame.join of                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
# ...

# %%
df.rename(columns={"hlpi_name": "name", "expenditure": "cost"}) ##Alter axes labels...Function / dict 
#values must benunique (1-to-1). Labels not contained in a dict / Series will be left as-is. Extra 
#labels listed don’t throw an error.
# Out:
#                              name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income    cost  eqv_income  \
# ...

# %%
df.set_index('year') #Set the index to become the ‘year’ column.Set the DataFrame index (row labels) 
#using one or more existing columns or arrays (of the correct length). The index can replace the 
#existing index or expand on it.
# Out:
#                           hlpi_name   hlpi  tot_hhs      own  own_wm  \
# year
# 2008                 All households  allhh  1560859  1087580  574406
# 2008                    Beneficiary  benef   185965    71256   39405
# 2008        Income quintile 1 (low)  disq1   312376   191470   48424
# 2008              Income quintile 2  disq2   312333   196203   84171
# 2008              Income quintile 3  disq3   312240   217657  141318
# ...                             ...    ...      ...      ...     ...
# 2020         Expenditure quintile 3  expq3   352564   213893  119637
# 2020         Expenditure quintile 4  expq4   350182   235256  141104
# 2020  Expenditure quintile 5 (high)  expq5   351328   288779  187838
# 2020                          Māori  maori   329588   156459  107753
# 2020                 Superannuitant  super   388013   314154   38270
#
#       own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# year
# ...

# %%
df.set_index(['year', 'age'])##Create a MultiIndex using columns ‘year’ and ‘age’
# Out:
#                                hlpi_name   hlpi  tot_hhs      own  own_wm  \
# year age
# 2008 35.9                 All households  allhh  1560859  1087580  574406
#      29.9                    Beneficiary  benef   185965    71256   39405
#      40.0        Income quintile 1 (low)  disq1   312376   191470   48424
#      34.7              Income quintile 2  disq2   312333   196203   84171
#      31.5              Income quintile 3  disq3   312240   217657  141318
# ...                                  ...    ...      ...      ...     ...
# 2020 36.9         Expenditure quintile 3  expq3   352564   213893  119637
#      35.0         Expenditure quintile 4  expq4   350182   235256  141104
#      39.6  Expenditure quintile 5 (high)  expq5   351328   288779  187838
#      31.1                          Māori  maori   329588   156459  107753
#      69.8                 Superannuitant  super   388013   314154   38270
#
# ...

# %%
df.to_csv()##If path_or_buf is None, returns the resulting csv format as a string. Otherwise returns 
#None.
# Out:
# ',hlpi_name,year,hlpi,tot_hhs,own,own_wm,own_prop,own_wm_prop,prop_hhs,age,size,income,expenditure,eqv_income,eqv_exp\r\n0,All households,2008,allhh,1560859,1087580,574406,69.7,36.8,100.0,35.9,2.7,46704,42394,26869,25132\r\n1,Beneficiary,2008,benef,185965,71256,39405,38.3,21.2,11.9,29.9,2.6,23404,25270,14258,15824\r\n2,Income quintile 1 (low),2008,disq1,312376,191470,48424,61.3,15.5,20.0,40.0,2.3,16747,21145,13402,14408\r\n3,Income quintile 2,2008,disq2,312333,196203,84171,62.8,26.9,20.0,34.7,2.8,31308,29855,18917,18266\r\n4,Income quintile 3,2008,disq3,312240,217657,141318,69.7,45.3,20.0,31.5,3.0,49106,46561,26870,24672\r\n5,Income quintile 4,2008,disq4,312336,229014,147658,73.3,47.3,20.0,35.3,2.6,61674,52776,36691,31958\r\n6,Income quintile 5 (high),2008,disq5,311574,253235,152835,81.3,49.1,20.0,39.3,2.5,96861,72822,55637,42932\r\n7,Expenditure quintile 1 (low),2008,expq1,312761,194358,49448,62.1,15.8,20.0,38.7,2.5,23680,16413,15190,11015\r\n8,Expenditure quintile 2,2008,expq2,3119
# ...

# %%
df.mean() ##Return the mean of the values over the requested axis.
# Out:
# C:\Users\ELCOT\AppData\Local\Temp/ipykernel_4840/3782172296.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean() ##Return the mean of the values over the requested axis.
# year             2014.000000
# tot_hhs        412519.271429
# own            268971.100000
# own_wm         129639.457143
# own_prop           63.505714
# own_wm_prop        30.348571
# prop_hhs           24.985714
# age                38.284286
# size                2.625714
# income          56694.785714
# expenditure     49267.128571
# eqv_income      33451.500000
# eqv_exp         29510.471429
# dtype: float64

# %%
df.median() ##Return the median of the values over the requested axis.
# Out:
# C:\Users\ELCOT\AppData\Local\Temp/ipykernel_4840/2005725065.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median() ##Return the median of the values over the requested axis.
# year             2014.00
# tot_hhs        327634.00
# own            215306.50
# own_wm         107909.00
# own_prop           64.20
# own_wm_prop        32.65
# prop_hhs           20.00
# age                36.60
# size                2.70
# income          52429.50
# expenditure     44887.00
# eqv_income      28454.50
# eqv_exp         25763.50
# dtype: float64

# %%
df.std() ##Return sample standard deviation over requested axis
# Out:
# C:\Users\ELCOT\AppData\Local\Temp/ipykernel_4840/2112978240.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std() ##Return sample standard deviation over requested axis
# year                4.273274
# tot_hhs        349154.700542
# own            238523.033142
# own_wm         128627.124758
# own_prop           15.145257
# own_wm_prop        14.010004
# prop_hhs           21.102368
# age                 9.376345
# size                0.350439
# income          28921.315551
# expenditure     24008.560485
# eqv_income      16004.914882
# eqv_exp         13307.606051
# dtype: float64

# %%
df.corr() ##DataFrame.corr(method='pearson', min_periods=1)[source]
##Compute pairwise correlation of columns, excluding NA/null values.

##Parameters
#method{‘pearson’, ‘kendall’, ‘spearman’} or callable
#Method of correlation:

#pearson : standard correlation coefficient

#kendall : Kendall Tau correlation coefficient

#spearman : Spearman rank correlation

#callable: callable with input two 1d ndarrays and returning a float. Note that the returned matrix from corr will have 1 along
#the diagonals and will be symmetric regardless of the callable’s behavior.

#min_periodsint, optional
#Minimum number of observations required per pair of columns to have a valid result. Currently only available for Pearson and 
#Spearman correlation.

#Returns DataFrame Correlation matrix.
# Out:
#                  year   tot_hhs       own    own_wm  own_prop  own_wm_prop  \
# year         1.000000  0.053009  0.026657  0.015618 -0.100903    -0.062819
# tot_hhs      0.053009  1.000000  0.984288  0.935600  0.134783     0.092174
# own          0.026657  0.984288  1.000000  0.946960  0.298236     0.173458
# own_wm       0.015618  0.935600  0.946960  1.000000  0.261673     0.429641
# own_prop    -0.100903  0.134783  0.298236  0.261673  1.000000     0.500671
# own_wm_prop -0.062819  0.092174  0.173458  0.429641  0.500671     1.000000
# prop_hhs     0.004677  0.997975  0.984529  0.936748  0.139761     0.095922
# age          0.071943  0.014830  0.121647 -0.135136  0.589219    -0.340870
# size         0.069680  0.004001 -0.088291  0.149775 -0.449625     0.376403
# income       0.255323  0.046177  0.139258  0.331920  0.542200     0.846988
# expenditure  0.237678  0.045830  0.142952  0.347219  0.552419     0.885802
# ...

# %%
len(df) ##returns total number of rows
# Out:
# 70

# %%
df.max() ##eturn the maximum over the requested axis.
# Out:
# hlpi_name      Superannuitant
# year                     2020
# hlpi                    super
# tot_hhs               1756740
# own                   1125000
# own_wm                 574662
# own_prop                 88.1
# own_wm_prop              58.2
# prop_hhs                100.0
# age                      70.3
# size                      3.2
# income                 146672
# expenditure            123424
# eqv_income              79607
# eqv_exp                 71985
# dtype: object

# %%
df.min() ##Return the minimum of the values over the requested axis.
# Out:
# hlpi_name      All households
# year                     2008
# hlpi                    allhh
# tot_hhs                132215
# own                     30080
# own_wm                  14220
# own_prop                 22.8
# own_wm_prop               5.1
# prop_hhs                  7.8
# age                      27.3
# size                      1.6
# income                  16747
# expenditure             16413
# eqv_income              13402
# eqv_exp                 11015
# dtype: object

# %%
df ##print the whole csv file
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...
